# %% [markdown]
# # Practical 8

# %% [markdown]
# ## Introduction to Data Mining

# %% [markdown]
# ### Ensemble Methods

# %% [markdown]
# "Ensembles" are an approach for making predictions that involves combining several models together.
#
# The concept is illustrated below. A logistic regression model, a decision tree and a k nearest neighbours model are comb
#
# ![title](images/ensembles.png)
